# %% [markdown]
# ### Downloading Data

# %% [markdown]
# Downloading just one year to start: 2020

# %%
import requests
import time
import os
import csv 
import pandas as pd

from zipfile import ZipFile

from io import BytesIO

# %%
datase_url = f'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_{year}-{month}.csv'

# %%
jan_2017_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-01.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_96474/2761539808.py in <module>
# ----> 1 jan_2017_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-01.csv')
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
## Reading in all yellow taxi data for 2020
jan_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv')
feb_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv')
mar_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-03.csv')
apr_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-04.csv')
may_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-05.csv')
jun_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv')
jul_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-07.csv')
aug_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-08.csv')
sep_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-09.csv')
oct_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-10.csv')
nov_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-11.csv')
dec_2020_taxi = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-12.csv')

# %%
# jan_2020_taxi.to_csv('./data/2020_taxi/taxi_jan.csv')
feb_2020_taxi.to_csv('./data/2020_taxi/taxi_feb.csv')
mar_2020_taxi.to_csv('./data/2020_taxi/taxi_mar.csv')
apr_2020_taxi.to_csv('./data/2020_taxi/taxi_apr.csv')
may_2020_taxi.to_csv('./data/2020_taxi/taxi_may.csv')
jun_2020_taxi.to_csv('./data/2020_taxi/taxi_jun.csv')
jul_2020_taxi.to_csv('./data/2020_taxi/taxi_jul.csv')
aug_2020_taxi.to_csv('./data/2020_taxi/taxi_aug.csv')
sep_2020_taxi.to_csv('./data/2020_taxi/taxi_sep.csv')
oct_2020_taxi.to_csv('./data/2020_taxi/taxi_oct.csv')
nov_2020_taxi.to_csv('./data/2020_taxi/taxi_nov.csv')
dec_2020_taxi.to_csv('./data/2020_taxi/taxi_dec.csv')

# %%
base_url ='https://s3.amazonaws.com/nyc-tlc/trip+data/'
for year in range(2018, 2020 + 1):
    for month in range(1,13):
        ## months under 10 start with a 0 in the file names
        if month < 10:
            month = f'{month:02}'
        else:
            month
        ## loading as csv
        x = pd.read_csv(f'{base_url}yellow_tripdata_{year}-{month}.csv')
        ##Making folder for the rear
        # os.mkdir(f'./data/{year}_taxi')
        ##saving file
        x.to_csv(f'./data/{month}_{year}_taxi.csv')
# Out:
# /Users/jonathanbeltran/opt/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
jan_2018 = pd.read_csv('./data/2018_taxi/01_2018_taxi.csv')

# %%
# jan_2018
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                 0         1  2018-01-01 00:21:05   2018-01-01 00:24:23
# 1                 1         1  2018-01-01 00:44:55   2018-01-01 01:03:05
# 2                 2         1  2018-01-01 00:08:26   2018-01-01 00:14:21
# 3                 3         1  2018-01-01 00:20:22   2018-01-01 00:52:51
# 4                 4         1  2018-01-01 00:09:18   2018-01-01 00:27:06
# ...             ...       ...                  ...                   ...
# 8759869     8759869         1  2018-01-31 23:21:35   2018-01-31 23:34:20
# 8759870     8759870         1  2018-01-31 23:35:51   2018-01-31 23:38:57
# 8759871     8759871         2  2018-01-31 23:28:00   2018-01-31 23:37:09
# 8759872     8759872         2  2018-01-31 23:24:40   2018-01-31 23:25:28
# 8759873     8759873         2  2018-01-31 23:28:16   2018-01-31 23:28:38
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
get_taxi_data(2018,2020)
