# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
# Import the autocorrelation function (ACF) plot.
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

from statsmodels.tsa.api import VAR

# %%
taxi_queens = pd.read_csv('./data/queens_full.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31234/760721546.py in <module>
# ----> 1 taxi_queens = pd.read_csv('./data/queens_full.csv')
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
taxi_queens.head(2)
# Out:
#    Unnamed: 0      pickup_datetime  VendorID  dropoff_datetime  \
# 0           4  2020-01-01 00:09:44       2.0               NaN
# 1          14  2020-01-01 00:08:21       2.0               NaN
#
#    passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# 0              1.0           0.03         1.0                 NaN
# 1              1.0           8.45         1.0                 NaN
#
#    PULocationID  DOLocationID  ...  month  year  pickup_day_of_week  \
# 0             7           NaN  ...    jan  2020           Wednesday
# 1           138           NaN  ...    jan  2020           Wednesday
#
#    dropoff_day_of_week  pickup_hour  dropoff_hour  pickup_timeofday  \
# 0            Wednesday            0             0        Late night
# 1            Wednesday            0             0        Late night
#
#    pickup_borough  dropoff_borough               zone
# 0          Queens           Queens            Astoria
# 1          Queens           Queens  LaGuardia Airport
#
# [2 rows x 29 columns]

# %%
# taxi_manhattan['pickup_datetime'] = taxi_manhattan['Unnamed: 0']

# %%
taxi_queens['pickup_datetime'] = pd.to_datetime(taxi_queens['pickup_datetime'])

# %%
taxi_queens = taxi_queens.drop(columns='Unnamed: 0')

# %%
taxi_queens.head(2)
# Out:
#       pickup_datetime  VendorID  dropoff_datetime  passenger_count  \
# 0 2020-01-01 00:09:44       2.0               NaN              1.0
# 1 2020-01-01 00:08:21       2.0               NaN              1.0
#
#    trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.03         1.0                 NaN             7           NaN
# 1           8.45         1.0                 NaN           138           NaN
#
#    payment_type  ...  month  year  pickup_day_of_week  dropoff_day_of_week  \
# 0           2.0  ...    jan  2020           Wednesday            Wednesday
# 1           2.0  ...    jan  2020           Wednesday            Wednesday
#
#    pickup_hour  dropoff_hour  pickup_timeofday  pickup_borough  \
# 0            0             0        Late night          Queens
# 1            0             0        Late night          Queens
#
#   dropoff_borough               zone
# 0          Queens            Astoria
# 1          Queens  LaGuardia Airport
#
# [2 rows x 28 columns]

# %%
taxi_queens.dtypes
# Out:
# pickup_datetime          datetime64[ns]
# VendorID                        float64
# dropoff_datetime                float64
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag              float64
# PULocationID                      int64
# DOLocationID                    float64
# payment_type                    float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# month                            object
# year                              int64
# pickup_day_of_week               object
# dropoff_day_of_week              object
# pickup_hour                       int64
# dropoff_hour                      int64
# pickup_timeofday                 object
# pickup_borough                   object
# dropoff_borough                  object
# zone                             object
# dtype: object

# %%
taxi_queens.set_index('pickup_datetime', inplace=True)

# %%
taxi_queens.reset_index()
taxi_queens.sort_index(inplace=True)

# %%
taxi_queens.head(2)
# Out:
#                      VendorID  dropoff_datetime  passenger_count  \
# pickup_datetime
# 2019-01-15 20:33:57       1.0               NaN              1.0
# 2019-01-18 16:08:04       1.0               NaN              4.0
#
#                      trip_distance  RatecodeID  store_and_fwd_flag  \
# pickup_datetime
# 2019-01-15 20:33:57            1.0         1.0                 NaN
# 2019-01-18 16:08:04           20.7         2.0                 NaN
#
#                      PULocationID  DOLocationID  payment_type  fare_amount  \
# pickup_datetime
# 2019-01-15 20:33:57           223           NaN           1.0          5.5
# 2019-01-18 16:08:04           132           NaN           1.0         52.0
#
#                      ...  month  year  pickup_day_of_week  \
# pickup_datetime      ...
# 2019-01-15 20:33:57  ...    jan  2019             Tuesday
# 2019-01-18 16:08:04  ...    jan  2019              Friday
#
#                      dropoff_day_of_week  pickup_hour  dropoff_hour  \
# pickup_datetime
# 2019-01-15 20:33:57              Tuesday           20            20
# 2019-01-18 16:08:04               Friday           16            17
#
#                      pickup_timeofday pickup_borough  dropoff_borough  \
# pickup_datetime
# 2019-01-15 20:33:57           Evening         Queens           Queens
# 2019-01-18 16:08:04           Evening         Queens        Manhattan
#
#                             zone
# pickup_datetime
# 2019-01-15 20:33:57     Steinway
# 2019-01-18 16:08:04  JFK Airport
#
# [2 rows x 27 columns]

# %%
# Code modified from code written by Matthew Garton.

def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    legend_list = []
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        legend_list.append(col)
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=13)
    plt.xticks(df.index[0::steps], fontsize=12)
    
    plt.legend(legend_list);

# %%
df.index[0, 5, 10, 15, 20, 25, steps]

# %%
# taxi_manhattan.resample('H',closed='right')[['passenger_count',
#        'trip_distance', 'payment_type', 'fare_amount',
#        'tip_amount', 'tolls_amount', 'total_amount', 'congestion_surcharge']].sum()

# %%
# Our dataset is per ride and we converted it to a timeseries by day. 
# We will evaluate monthly, weekly, daily and 3hour window resampled timeseries. 
# Monthly has only 11*12 = 132 observations, weekly has 6864 and daily has 2505360. We wont need more data so will not spend much time on the 3hour modeling

# # Create new df for modeling which has the columns we need, by month
df_model = taxi_queens.resample("M").sum()[['passenger_count','trip_distance', 'fare_amount',
                                               'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# # Create new df for modeling which has the columns we need, by week
df_model_week = taxi_queens.resample("W").sum()[['passenger_count','trip_distance', 'fare_amount',
                                                    'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# Create new df for modeling which has the columns we need, by day 
df_model_day = taxi_queens.resample("D").sum()[['passenger_count','trip_distance', 'fare_amount','tip_amount', 'tolls_amount', 'congestion_surcharge']]

# Create new df for modeling which has the columns we need, by 3 hour window

df_model_3hour = taxi_queens.resample("3H").sum()[['passenger_count','trip_distance', 'fare_amount',
                                                      'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# %%
# 
plot_series(df_model, cols=['passenger_count','trip_distance', 'fare_amount',
                            'tip_amount', 'tolls_amount', 'congestion_surcharge'], 
            title="Passenger Counts, Trip Distances, and Fare/Charge Types by Month-Queens ", steps = 12)

# %%
plot_series(df_model_week, cols=['passenger_count','trip_distance', 'fare_amount',
                            'tip_amount', 'tolls_amount', 'congestion_surcharge'], title=" Weekly Passenger Counts, Trip Distances, and Fare/Charge Types", steps = 52)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31234/1296313620.py in <module>
# ----> 1 plot_series(df_model_week, cols=['passenger_count','trip_distance', 'fare_amount',
#       2                             'tip_amount', 'tolls_amount', 'congestion_surcharge'], title=" Weekly Passenger Counts, Trip Distances, and Fare/Charge Types", steps = 52)
#
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31234/3134716473.py in plot_series(df, cols, title, xlab, ylab, steps)
#      23     # Enlarge tick marks.
#      24     plt.yticks(fontsize=13)
# ---> 25     plt.xticks(df.index[0, 5, 10, 15, 20,steps], fontsize=12)
#      26
#      27     plt.legend(legend_list);
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/extension.py in __getitem__(self, key)
#     277
#     278     def __getitem__(self, key):
# --> 279         result = self._data[key]
#     280         if isinstance(result, type(self._data)):
#     281             if result.ndim == 1:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     320         only handle list-likes, slices, and integer scalars
#     321         """
# --> 322         result = super().__getitem__(key)
#     323         if lib.is_scalar(result):
#     324             return result
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py in __getitem__(self, key)
#     205         )
#     206         key = check_array_indexer(self, key)
# --> 207         result = self._ndarray[key]
#     208         if lib.is_scalar(result):
#     209             return self._box_func(result)
#
# IndexError: too many indices for array: array is 1-dimensional, but 6 were indexed

# %%
df_model_week.head()
# Out:
#                  passenger_count  trip_distance  fare_amount  tip_amount  \
# pickup_datetime
# 2019-01-20                  49.0         342.63       931.50      158.18
# 2019-01-27              166954.0     1212466.20   3719495.16   571312.09
# 2019-02-03              152227.0     1099965.58   3392971.84   517834.83
# 2019-02-10              161641.0     1165665.44   3610337.36   578336.99
# 2019-02-17              156270.0     1119680.90   3496149.79   530538.91
#
#                  tolls_amount  congestion_surcharge
# pickup_datetime
# 2019-01-20              69.12                  0.00
# 2019-01-27          305156.29                  0.00
# 2019-02-03          281506.07              31575.25
# 2019-02-10          313424.92             142960.75
# 2019-02-17          292901.23             128037.75

# %%
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic','p-value', 'Lag Used'])
    return dfoutput

# %% [markdown]
# ### We're using Vector AutoRegressive Time series for modeling.
# We need to confirm stationarity of the data.
#
# Do the ADF (Augmented Dickey Fuller) statistical Test to confirm stationarity of the time series variables. If needed, do a diff one or more times until stationarity is achieved.

# %%
interpret_dftest(adfuller(df_model['passenger_count']))
# Out:
# Test Statistic   -1.136289
# p-value           0.700386
# Lag Used          1.000000
# dtype: float64

# %%
##Not stationary

# %%
interpret_dftest(adfuller(df_model['passenger_count'].diff().dropna())) #
# Out:
# Test Statistic   -4.712383
# p-value           0.000080
# Lag Used          0.000000
# dtype: float64

# %%
# This is now stationary

# %%
# Create column.

df_model['first_diff_passenger_count'] = df_model['passenger_count'].diff()

# %%
df_model['first_diff_passenger_count'].plot();

# %%
interpret_dftest(adfuller(df_model['trip_distance']))
# Out:
# Test Statistic   -1.192374
# p-value           0.676868
# Lag Used          1.000000
# dtype: float64

# %%
interpret_dftest(adfuller(df_model['trip_distance'].diff().dropna()))
# Out:
# Test Statistic   -4.623320
# p-value           0.000117
# Lag Used          0.000000
# dtype: float64

# %%
df_model['first_diff_trip_distance'] = df_model['trip_distance'].diff()

# %%
df_model['first_diff_trip_distance'].plot();

# %%
interpret_dftest(adfuller(df_model['fare_amount'].diff().dropna()))
# Out:
# Test Statistic   -4.975127
# p-value           0.000025
# Lag Used          0.000000
# dtype: float64

# %%
df_model['first_diff_fare_amount'] = df_model['fare_amount'].diff()

# %%
df_model['first_diff_fare_amount'].plot();

# %%
interpret_dftest(adfuller(df_model['congestion_surcharge'].diff().dropna()))
# Out:
# Test Statistic   -7.336959e+00
# p-value           1.090176e-10
# Lag Used          0.000000e+00
# dtype: float64

# %%
df_model['first_diff_congestion_surcharge']= df_model['congestion_surcharge'].diff()

# %%
df_model['first_diff_congestion_surcharge'].plot();

# %%
interpret_dftest(adfuller(df_model['tip_amount'].diff().dropna()))
# Out:
# Test Statistic   -4.876295
# p-value           0.000039
# Lag Used          0.000000
# dtype: float64

# %%
df_model['first_diff_tip_amount'] = df_model['tip_amount'].diff()

# %%
interpret_dftest(adfuller(df_model['tolls_amount'].diff().dropna())) #stationary!
# Out:
# Test Statistic   -4.836777
# p-value           0.000046
# Lag Used          0.000000
# dtype: float64

# %%
df_model['first_diff_tolls_amount'] = df_model['tolls_amount'].diff()

# %%
df_model.head(20)
# Out:
#                  passenger_count  trip_distance  fare_amount  tip_amount  \
# pickup_datetime
# 2019-01-31              255036.0     1849557.39   5694923.56   876107.85
# 2019-02-28              663144.0     4799845.91  15525274.70  2317042.98
# 2019-03-31              813070.0     5856076.21  18364491.42  2756656.76
# 2019-04-30              787042.0     5640772.93  17560570.33  2558241.53
# 2019-05-31              822789.0     5927739.94  18692979.80  2703068.75
# 2019-06-30              781556.0     5642167.98  17650504.24  2577996.20
# 2019-07-31              740631.0     5282341.63  16519779.56  2315640.17
# 2019-08-31              748683.0     5299693.97  16961277.84  2250126.47
# 2019-09-30              713868.0     5261852.44  16827367.12  2394954.34
# 2019-10-31              739829.0     5452881.88  17274728.67  2502614.21
# 2019-11-30              655231.0     4802053.11  15221833.29  2221385.63
# 2019-12-31              698491.0     5015660.60  15949011.16  2297210.51
# 2020-01-31              599368.0     4485303.36  13922439.21  2060456.43
# 2020-02-29              531000.0     3972956.17  12383864.25  1830832.67
# 2020-03-31              246508.0     1787147.84   5548501.87   754695.17
# 2020-04-30                7993.0       53731.57    164592.82    17035.29
# 2020-05-31               13161.0       88862.81    274605.83    30613.38
# 2020-06-30               33962.0      251002.86    756930.72    97594.97
# 2020-07-31               48178.0      346287.85   1040945.36   130867.82
# 2020-08-31               62491.0      471498.84   1409204.27   174852.97
#
#                  tolls_amount  congestion_surcharge  \
# pickup_datetime
# 2019-01-31          472483.16                  0.00
# 2019-02-28         1248399.63             531747.75
# 2019-03-31         1492505.00             647109.75
# 2019-04-30         1480617.15             611660.75
# 2019-05-31         1561369.32             633803.25
# 2019-06-30         1460095.59             591235.00
# 2019-07-31         1321857.41             533034.00
# 2019-08-31         1319501.76             518950.00
# 2019-09-30         1333160.33             545010.75
# 2019-10-31         1417186.05             585365.75
# 2019-11-30         1240988.51             513341.00
# 2019-12-31         1274148.91             526300.50
# 2020-01-31         1083378.20             446002.50
# 2020-02-29          966570.76             403985.50
# 2020-03-31          390343.97             160897.50
# 2020-04-30            9138.51               4070.00
# 2020-05-31           16054.25               7070.00
# 2020-06-30           50438.27              18612.50
# 2020-07-31           70335.64              24505.00
# 2020-08-31           92819.42              32502.50
#
#                  first_diff_passenger_count  seconf_diff_trip_distance  \
# pickup_datetime
# 2019-05-31                              22142.50              144827.22
# 2019-06-30                             -42568.25             -125072.55
# 2019-07-31                             -58201.00             -262356.03
# 2019-08-31                             -14084.00              -65513.70
# 2019-09-30                              26060.75              144827.87
# 2019-10-31                              40355.00              107659.87
# 2019-11-30                             -72024.75             -281228.58
# 2019-12-31                              12959.50               75824.88
# 2020-01-31                             -80298.00             -236754.08
# 2020-02-29                             -42017.00             -229623.76
# 2020-03-31                            -243088.00            -1076137.50
# 2020-04-30                            -156827.50             -737659.88
# 2020-05-31                               3000.00               13578.09
# 2020-06-30                              11542.50               66981.59
# 2020-07-31                               5892.50               33272.85
# 2020-08-31                               7997.50               43985.15
#
#                  first_diff_tolls_amount
# pickup_datetime
# 2019-01-31                           NaN
# 2019-02-28                     775916.47
# 2019-03-31                     244105.37
# 2019-04-30                     -11887.85
# 2019-05-31                      80752.17
# 2019-06-30                    -101273.73
# 2019-07-31                    -138238.18
# 2019-08-31                      -2355.65
# 2019-09-30                      13658.57
# 2019-10-31                      84025.72
# 2019-11-30                    -176197.54
# 2019-12-31                      33160.40
# 2020-01-31                    -190770.71
# 2020-02-29                    -116807.44
# 2020-03-31                    -576226.79
# 2020-04-30                    -381205.46
# 2020-05-31                       6915.74
# 2020-06-30                      34384.02
# 2020-07-31                      19897.37
# 2020-08-31                      22483.78

# %% [markdown]
# Use the coefficient of correlation between two values in a time series, the autocorrelation function (ACF), to identify seasonality in our time series data.
#
# Use the ACF plot, a bar chart of the coefficients of correlation between a time series and lags of itself, to pick the points that are statistically significant (outside the blue shaded Confidence Interval region).
#
# Use the Partial autocorrelation (PACF), a statistical measure that captures the correlation between two variables after controlling for the effects of other variables, to confirm the statistically significant lags.

# %%
plot_acf(df_model['passenger_count'], lags=23);

# %%
# Generate the PACF plot 

plot_pacf( df_model['passenger_count'], lags=11);

# %%
df_model.columns
# Out:
# Index(['passenger_count', 'trip_distance', 'fare_amount', 'tip_amount',
#        'tolls_amount', 'congestion_surcharge', 'first_diff_passenger_count',
#        'seconf_diff_trip_distance', 'second_diff_fare_amount',
#        'third_diff_congestion_surcharge', 'first_diff_trip_distance',
#        'first_diff_fare_amount', 'first_diff_congestion_surcharge',
#        'first_diff_tip_amount', 'first_diff_tolls_amount'],
#       dtype='object')

# %%
# Subset our data. Use our differenced columns
df_ts = df_model[['first_diff_passenger_count','second_diff_fare_amount',
       'third_diff_congestion_surcharge', 'first_diff_trip_distance',
       'first_diff_fare_amount', 'first_diff_congestion_surcharge',
       'first_diff_tip_amount', 'first_diff_tolls_amount']]

# Let's get rid of rows containing missing values.
df_ts.dropna(inplace = True)

df_ts
# Out:
# /Users/jonathanbeltran/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#
# 2019-03-31                   439613.78                244105.37
# 2019-04-30                  -198415.23                -11887.85
# 2019-05-31                   144827.22                 80752.17
# 2019-06-30                  -125072.55               -101273.73
# 2019-07-31                  -262356.03               -138238.18
# 2019-08-31                   -65513.70                 -2355.65
# 2019-09-30                   144827.87                 13658.57
# 2019-10-31                   107659.87                 84025.72
# 2019-11-30                  -281228.58               -176197.54
# 2019-12-31                    75824.88                 33160.40
# 2020-01-31                  -236754.08               -190770.71
# 2020-02-29                  -229623.76               -116807.44
# 2020-03-31                 -1076137.50               -576226.79
# 2020-04-30                  -737659.88               -381205.46
# 2020-05-31                    13578.09                  6915.74
# 2020-06-30                    66981.59                 34384.02
# 2020-07-31                    33272.85                 19897.37
# 2020-08-31                    43985.15                 22483.78
# 2020-09-30                    12516.92                  6532.57
# 2020-10-31                    26079.37                 12794.83
# 2020-11-30                   -24985.68                -14976.76
# 2020-12-31                     2380.15                  -681.31

# %%
train, test = train_test_split(df_ts, shuffle=False, 
                               test_size = 0.05) # use small test size, as we can't predict far into the future
# Out of 131 rows (dropped one null), train has 124 and test has 7

# %%
# Instantiate a VAR model. 

model = VAR(train, dates = train.index, freq='M')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2 entries, 2020-11-30 to 2020-12-31
# Freq: M
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   first_diff_passenger_count       2 non-null      float64
#  1   second_diff_fare_amount          2 non-null      float64
#  2   third_diff_congestion_surcharge  2 non-null      float64
#  3   first_diff_trip_distance         2 non-null      float64
#  4   first_diff_fare_amount           2 non-null      float64
#  5   first_diff_congestion_surcharge  2 non-null      float64
#  6   first_diff_tip_amount            2 non-null      float64
#  7   first_diff_tolls_amount          2 non-null      float64
# dtypes: float64(8)
# memory usage: 144.0 bytes

# %%
# Fit our model and use AIC to select the value of p.

ts_model = model.fit()   # what "information criterion" (ic) will we use to decide what's "best?"

# %%
# What is the order of our autoregressive model? 
# Order ‘p’ means, up to p-lags of Y are used and they are the predictors in the equation
ts_model.k_ar
# Out:
# 1

# %%
# Check out the summary of our model!
ts_model.summary()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31234/3789745628.py in <module>
#       1 # Check out the summary of our model!
# ----> 2 ts_model.summary()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/var_model.py in summary(self)
#    1833         summary : VARSummary
#    1834         """
# -> 1835         return VARSummary(self)
#    1836
#    1837     def irf(self, periods=10, var_decomp=None, var_order=None):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/output.py in __init__(self, estimator)
#      69     def __init__(self, estimator):
#      70         self.model = estimator
# ---> 71         self.summary = self.make()
#      72
#      73     def __repr__(self):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/output.py in make(self, endog_names, exog_names)
#      81
#      82         buf.write(self._header_table() + '\n')
# ---> 83         buf.write(self._stats_table() + '\n')
#      84         buf.write(self._coef_table() + '\n')
#      85         buf.write(self._resid_info() + '\n')
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/output.py in _stats_table(self)
#     128                        'FPE:',
#     129                        'Det(Omega_mle):')
# --> 130         part2Ldata = [[model.neqs], [model.nobs], [model.llf], [model.aic]]
#     131         part2Rdata = [[model.bic], [model.hqic], [model.fpe], [model.detomega]]
#     132         part2Lheader = None
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/var_model.py in llf(self)
#    1538     def llf(self):
#    1539         "Compute VAR(p) loglikelihood"
# -> 1540         return var_loglike(self.resid, self.sigma_u_mle, self.nobs)
#    1541
#    1542     @cache_readonly
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/vector_ar/var_model.py in var_loglike(resid, omega, nobs)
#     332         \left(\ln\left|\Omega\right|-K\ln\left(2\pi\right)-K\right)
#     333     """
# --> 334     logdet = logdet_symm(np.asarray(omega))
#     335     neqs = len(omega)
#     336     part1 = -(nobs * neqs / 2) * np.log(2 * np.pi)
#
# ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tools/linalg.py in logdet_symm(m, check_symm)
#      26         if not np.all(m == m.T):  # would be nice to short-circuit check
#      27             raise ValueError("m is not symmetric.")
# ---> 28     c, _ = linalg.cho_factor(m, lower=True)
#      29     return 2*np.sum(np.log(c.diagonal()))
#      30
#
# ~/opt/miniconda3/lib/python3.9/site-packages/scipy/linalg/decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     150
#     151     """
# --> 152     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
#     153                          check_finite=check_finite)
#     154     return c, lower
#
# ~/opt/miniconda3/lib/python3.9/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      36     if info > 0:
# ---> 37         raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                           "definite" % info)
#      39     if info < 0:
#
# LinAlgError: 5-th leading minor of the array is not positive definite

# %%
# Plot our training data.
ts_model.plot();
plt.tight_layout()

# %%
# Plot the forecast looking 10 steps ahead.
ts_model.plot_forecast(steps=6);
plt.tight_layout()

# %%
# Plot the forecast looking 11 steps ahead.
ts_model.plot_forecast(steps=12);
plt.tight_layout()

# %%
#Plot the forecast for the whole test set (and overlay the actual test values)
model_axes = ts_model.plot_forecast(test.shape[0]);
for i,ax in enumerate(model_axes.get_axes()):
     plot_df = test.iloc[:,i].reset_index(drop = True)
     plot_df.index += len(train)
     plot_df.plot(ax = ax, label = test.columns[i], color = 'red', alpha = 0.5)
     # zoom in 
     #plt.xlim(plot_df.index[-6], plot_df.index[-1])
     #plt.xlim(y_train.index[-15], y_test.index[-1])
     
     ax.legend(loc=2) # upper left
plt.tight_layout();

# %%
##Evaluating

# %%
# We'll use RMSE

# Save forecasted values
forecast = ts_model.forecast(train.values, len(test))

# Loop through columns and get RMSE for each
for i in range(test.shape[1]):
    print(f'The test RMSE on the {test.columns[i]} data is: {round(mean_squared_error(squared=False, y_true=test.values[:, i], y_pred=forecast[:, i]), 4)}')
# Out:
# The test RMSE on the first_diff_passenger_count data is: 29149.5298
# The test RMSE on the second_diff_fare_amount data is: 639888.5014
# The test RMSE on the third_diff_congestion_surcharge data is: 24168.7398
# The test RMSE on the first_diff_trip_distance data is: 201196.645
# The test RMSE on the first_diff_fare_amount data is: 639888.5014
# The test RMSE on the first_diff_congestion_surcharge data is: 24168.7398
# The test RMSE on the first_diff_tip_amount data is: 101958.8137
# The test RMSE on the first_diff_tolls_amount data is: 54107.7325

# %%
## Start by making a dataframe of our model's forecasts
forecast_df = pd.DataFrame(data = ts_model.forecast(train.values, len(test)),
                           columns = test.columns, index = test.index)

# %%
## Then we can undifference our once-differenced columns
### We do this by taking the last value from the original column before our test data
### and adding the cumulative summed first differenced forecasts
forecast_df['forecast_fatals'] = df_model['fatals'].iloc[-len(test)-1]  + forecast_df['first_diff_fatals'].cumsum()
forecast_df['forecast_drunk_dr'] = df_model['drunk_dr'].iloc[-len(test)-1]  + forecast_df['first_diff_drunk_dr'].cumsum()
forecast_df['forecast_peds'] = df_model['peds'].iloc[-len(test)-1]  + forecast_df['first_diff_peds'].cumsum()
