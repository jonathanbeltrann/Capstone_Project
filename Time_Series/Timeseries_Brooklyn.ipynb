# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
# Import the autocorrelation function (ACF) plot.
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

from statsmodels.tsa.api import VAR

# %%
taxi_manhattan = pd.read_csv('./data/brooklyn_full.csv')

# %%
taxi_manhattan.head(2)
# Out:
#    Unnamed: 0      pickup_datetime  VendorID  dropoff_datetime  \
# 0          70  2020-01-01 00:35:13       2.0               NaN
# 1         106  2020-01-01 00:12:28       2.0               NaN
#
#    passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# 0              2.0           4.55         1.0                 NaN
# 1              1.0           1.50         1.0                 NaN
#
#    PULocationID  DOLocationID  ...  month  year  pickup_day_of_week  \
# 0           189           NaN  ...    jan  2020           Wednesday
# 1            40           NaN  ...    jan  2020           Wednesday
#
#    dropoff_day_of_week  pickup_hour  dropoff_hour  pickup_timeofday  \
# 0            Wednesday            0             0        Late night
# 1            Wednesday            0             0        Late night
#
#    pickup_borough  dropoff_borough              zone
# 0        Brooklyn         Brooklyn  Prospect Heights
# 1        Brooklyn         Brooklyn   Carroll Gardens
#
# [2 rows x 29 columns]

# %%
# taxi_manhattan['pickup_datetime'] = taxi_manhattan['Unnamed: 0']

# %%
taxi_manhattan['pickup_datetime'] = pd.to_datetime(taxi_manhattan['pickup_datetime'])

# %%
taxi_manhattan = taxi_manhattan.drop(columns='Unnamed: 0')

# %%
taxi_manhattan.head(2)
# Out:
#       pickup_datetime  VendorID  dropoff_datetime  passenger_count  \
# 0 2020-01-01 00:35:13       2.0               NaN              2.0
# 1 2020-01-01 00:12:28       2.0               NaN              1.0
#
#    trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           4.55         1.0                 NaN           189           NaN
# 1           1.50         1.0                 NaN            40           NaN
#
#    payment_type  ...  month  year  pickup_day_of_week  dropoff_day_of_week  \
# 0           1.0  ...    jan  2020           Wednesday            Wednesday
# 1           1.0  ...    jan  2020           Wednesday            Wednesday
#
#    pickup_hour  dropoff_hour  pickup_timeofday  pickup_borough  \
# 0            0             0        Late night        Brooklyn
# 1            0             0        Late night        Brooklyn
#
#   dropoff_borough              zone
# 0        Brooklyn  Prospect Heights
# 1        Brooklyn   Carroll Gardens
#
# [2 rows x 28 columns]

# %%
taxi_manhattan.dtypes
# Out:
# pickup_datetime          datetime64[ns]
# VendorID                        float64
# dropoff_datetime                float64
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag              float64
# PULocationID                      int64
# DOLocationID                    float64
# payment_type                    float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# month                            object
# year                              int64
# pickup_day_of_week               object
# dropoff_day_of_week              object
# pickup_hour                       int64
# dropoff_hour                      int64
# pickup_timeofday                 object
# pickup_borough                   object
# dropoff_borough                  object
# zone                             object
# dtype: object

# %%
taxi_manhattan.set_index('pickup_datetime', inplace=True)

# %%
taxi_manhattan.reset_index()
taxi_manhattan.sort_index(inplace=True)

# %%
taxi_manhattan.columns

# %%
# Code modified from code written by Matthew Garton.

def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    legend_list = []
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        legend_list.append(col)
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=13)
    plt.xticks(df.index[0, 5, 10, 15, 20, 25, steps], fontsize=12)
    
    plt.legend(legend_list);

# %%
df.index[0, 5, 10, 15, 20, 25, steps]

# %%
# taxi_manhattan.resample('H',closed='right')[['passenger_count',
#        'trip_distance', 'payment_type', 'fare_amount',
#        'tip_amount', 'tolls_amount', 'total_amount', 'congestion_surcharge']].sum()

# %%
# Our dataset is per ride and we converted it to a timeseries by day. 
# We will evaluate monthly, weekly, daily and 3hour window resampled timeseries. 
# Monthly has only 11*12 = 132 observations, weekly has 6864 and daily has 2505360. We wont need more data so will not spend much time on the 3hour modeling

# # Create new df for modeling which has the columns we need, by month
df_model = taxi_manhattan.resample("M").sum()[['passenger_count','trip_distance', 'fare_amount',
                                               'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# # Create new df for modeling which has the columns we need, by week
df_model_week = taxi_manhattan.resample("W").sum()[['passenger_count','trip_distance', 'fare_amount',
                                                    'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# Create new df for modeling which has the columns we need, by day 
df_model_day = taxi_manhattan.resample("D").sum()[['passenger_count','trip_distance', 'fare_amount','tip_amount', 'tolls_amount', 'congestion_surcharge']]

# Create new df for modeling which has the columns we need, by 3 hour window

df_model_3hour = taxi_manhattan.resample("3H").sum()[['passenger_count','trip_distance', 'fare_amount',
                                                      'tip_amount', 'tolls_amount', 'congestion_surcharge']]

# %%
# 
plot_series(df_model, cols=['passenger_count','trip_distance', 'fare_amount',
                            'tip_amount', 'tolls_amount', 'congestion_surcharge'], 
            title="Passenger Counts, Trip Distances, and Fare/Charge Types by Month- Brooklyn ", steps = 12)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31690/2423296686.py in <module>
#       1 #
# ----> 2 plot_series(df_model, cols=['passenger_count','trip_distance', 'fare_amount',
#       3                             'tip_amount', 'tolls_amount', 'congestion_surcharge'],
#       4             title="Passenger Counts, Trip Distances, and Fare/Charge Types by Month- Brooklyn ", steps = 12)
#
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31690/4026256564.py in plot_series(df, cols, title, xlab, ylab, steps)
#      23     # Enlarge tick marks.
#      24     plt.yticks(fontsize=13)
# ---> 25     plt.xticks(df.index[0, 5, 10, 15, 20, 25, steps], fontsize=12)
#      26
#      27     plt.legend(legend_list);
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/extension.py in __getitem__(self, key)
#     277
#     278     def __getitem__(self, key):
# --> 279         result = self._data[key]
#     280         if isinstance(result, type(self._data)):
#     281             if result.ndim == 1:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     320         only handle list-likes, slices, and integer scalars
#     321         """
# --> 322         result = super().__getitem__(key)
#     323         if lib.is_scalar(result):
#     324             return result
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py in __getitem__(self, key)
#     205         )
#     206         key = check_array_indexer(self, key)
# --> 207         result = self._ndarray[key]
#     208         if lib.is_scalar(result):
#     209             return self._box_func(result)
#
# IndexError: too many indices for array: array is 1-dimensional, but 7 were indexed

# %%
plot_series(df_model_week, cols=['passenger_count','trip_distance', 'fare_amount',
                            'tip_amount', 'tolls_amount', 'congestion_surcharge'], title=" Weekly Passenger Counts, Trip Distances, and Fare/Charge Types", steps = 52)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31690/1296313620.py in <module>
# ----> 1 plot_series(df_model_week, cols=['passenger_count','trip_distance', 'fare_amount',
#       2                             'tip_amount', 'tolls_amount', 'congestion_surcharge'], title=" Weekly Passenger Counts, Trip Distances, and Fare/Charge Types", steps = 52)
#
# /var/folders/85/gfsz06392cx1589spz1jvvtc0000gn/T/ipykernel_31690/4026256564.py in plot_series(df, cols, title, xlab, ylab, steps)
#      23     # Enlarge tick marks.
#      24     plt.yticks(fontsize=13)
# ---> 25     plt.xticks(df.index[0, 5, 10, 15, 20, 25, steps], fontsize=12)
#      26
#      27     plt.legend(legend_list);
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/extension.py in __getitem__(self, key)
#     277
#     278     def __getitem__(self, key):
# --> 279         result = self._data[key]
#     280         if isinstance(result, type(self._data)):
#     281             if result.ndim == 1:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     320         only handle list-likes, slices, and integer scalars
#     321         """
# --> 322         result = super().__getitem__(key)
#     323         if lib.is_scalar(result):
#     324             return result
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py in __getitem__(self, key)
#     205         )
#     206         key = check_array_indexer(self, key)
# --> 207         result = self._ndarray[key]
#     208         if lib.is_scalar(result):
#     209             return self._box_func(result)
#
# IndexError: too many indices for array: array is 1-dimensional, but 7 were indexed

# %%
df_model_week.head()
# Out:
#                  passenger_count  trip_distance  fare_amount  tip_amount  \
# pickup_datetime
# 2019-01-06                  10.0          13.70        70.00       13.70
# 2019-01-13                   0.0           0.00         0.00        0.00
# 2019-01-20                 615.0         824.30      3586.50      512.63
# 2019-01-27             2486744.0     3428835.62  16535363.07  2533502.69
# 2019-02-03             2606921.0     3620649.44  17414977.59  2815831.86
#
#                  tolls_amount  congestion_surcharge
# pickup_datetime
# 2019-01-06               0.00                  0.00
# 2019-01-13               0.00                  0.00
# 2019-01-20               5.76                  0.00
# 2019-01-27          215987.79                  0.00
# 2019-02-03          226968.79             952152.25

# %%
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic','p-value', 'Lag Used'])
    return dfoutput

# %% [markdown]
# ### We're using Vector AutoRegressive Time series for modeling.
# We need to confirm stationarity of the data.
#
# Do the ADF (Augmented Dickey Fuller) statistical Test to confirm stationarity of the time series variables. If needed, do a diff one or more times until stationarity is achieved.

# %%
interpret_dftest(adfuller(df_model['passenger_count']))
# Out:
# Test Statistic   -0.829119
# p-value           0.810419
# Lag Used          0.000000
# dtype: float64

# %%
##Not stationary

# %%
interpret_dftest(adfuller(df_model['passenger_count'].diff().dropna())) #
# Out:
# Test Statistic   -6.207694e+00
# p-value           5.605459e-08
# Lag Used          0.000000e+00
# dtype: float64

# %%
# This is now stationary

# %%
# Create column.

df_model['first_diff_passenger_count'] = df_model['passenger_count'].diff()

# %%
df_model['first_diff_passenger_count'].plot();

# %%
interpret_dftest(adfuller(df_model['trip_distance']))
# Out:
# Test Statistic   -0.945410
# p-value           0.772651
# Lag Used          0.000000
# dtype: float64

# %%
interpret_dftest(adfuller(df_model['trip_distance'].diff().dropna()))
# Out:
# Test Statistic   -6.893492e+00
# p-value           1.337037e-09
# Lag Used          0.000000e+00
# dtype: float64

# %%
df_model['first_diff_trip_distance'] = df_model['trip_distance'].diff()

# %%
df_model['first_diff_trip_distance'].plot();

# %%
interpret_dftest(adfuller(df_model['fare_amount'].diff().dropna()))
# Out:
# Test Statistic   -6.639647e+00
# p-value           5.450676e-09
# Lag Used          0.000000e+00
# dtype: float64

# %%
df_model['first_diff_fare_amount'] = df_model['fare_amount'].diff()

# %%
df_model['first_diff_fare_amount'].plot();

# %%
interpret_dftest(adfuller(df_model['congestion_surcharge'].diff().dropna()))
# Out:
# Test Statistic   -6.960172e+00
# p-value           9.207938e-10
# Lag Used          0.000000e+00
# dtype: float64

# %%
df_model['first_diff_congestion_surcharge']= df_model['congestion_surcharge'].diff()

# %%
df_model['first_diff_congestion_surcharge'].plot();

# %%
interpret_dftest(adfuller(df_model['tip_amount'].diff().dropna()))
# Out:
# Test Statistic   -4.720973
# p-value           0.000077
# Lag Used          0.000000
# dtype: float64

# %%
df_model['first_diff_tip_amount'] = df_model['tip_amount'].diff()

# %%
interpret_dftest(adfuller(df_model['tolls_amount'])) #stationary!
# Out:
# Test Statistic   -2.691986
# p-value           0.075435
# Lag Used          8.000000
# dtype: float64

# %%
df_model.head(20)
# Out:
#                  passenger_count  trip_distance  fare_amount  tip_amount  \
# pickup_datetime
# 2019-01-31               42911.0      128813.48    486598.68    39569.84
# 2019-02-28              128493.0      383356.22   1449649.35   120574.39
# 2019-03-31              151263.0      442071.97   1680355.77   149790.04
# 2019-04-30              133612.0      353838.29   1376333.38   144144.83
# 2019-05-31              131148.0      342527.40   1363555.99   151324.45
# 2019-06-30              123112.0      322433.90   1293653.53   138721.53
# 2019-07-31               97412.0      250530.60    997831.27   107419.62
# 2019-08-31               90189.0      218208.06    867473.83   100934.72
# 2019-09-30              103883.0      251035.50   1024107.39   127242.97
# 2019-10-31              104480.0      253051.04   1026361.28   135034.10
# 2019-11-30               92122.0      222900.82    900818.09   117534.13
# 2019-12-31               93490.0      227541.85    916522.24   123745.19
# 2020-01-31               74238.0      185725.72    729615.21   100110.36
# 2020-02-29               78111.0      191244.41    761255.30   106685.42
# 2020-03-31               40737.0      107756.88    421496.92    54800.10
# 2020-04-30                3289.0       12788.46     43578.24     3532.99
# 2020-05-31                4545.0       16701.71     58317.26     5389.24
# 2020-06-30                5858.0       20651.26     74815.84     7438.45
# 2020-07-31                6579.0       22129.96     82544.73     7941.08
# 2020-08-31                7795.0       24976.80     94872.35     8867.10
#
#                  tolls_amount  congestion_surcharge  \
# pickup_datetime
# 2019-01-31           10022.99                  0.00
# 2019-02-28           28368.90              49322.25
# 2019-03-31           32596.98              58672.25
# 2019-04-30           23168.92              58375.00
# 2019-05-31           21668.34              57970.75
# 2019-06-30           18242.08              54194.50
# 2019-07-31           13889.73              45109.00
# 2019-08-31           10935.39              42833.50
# 2019-09-30           12839.81              50795.00
# 2019-10-31           12888.16              52504.75
# 2019-11-30           10933.44              44779.25
# 2019-12-31           11467.30              45435.50
# 2020-01-31           10945.40              39694.50
# 2020-02-29           10867.20              41151.75
# 2020-03-31            5825.50              21707.50
# 2020-04-30             974.67               1157.50
# 2020-05-31            1329.43               1805.00
# 2020-06-30            1731.74               2402.50
# 2020-07-31            1848.99               2970.00
# 2020-08-31            1828.72               3307.50
#
#                  first_diff_passenger_count  first_diff_trip_distance  \
# pickup_datetime
# 2019-01-31                              NaN                       NaN
# 2019-02-28                          85582.0                 254542.74
# 2019-03-31                          22770.0                  58715.75
# 2019-04-30                         -17651.0                 -88233.68
# 2019-05-31                          -2464.0                 -11310.89
# 2019-06-30                          -8036.0                 -20093.50
# 2019-07-31                         -25700.0                 -71903.30
# 2019-08-31                          -7223.0                 -32322.54
# 2019-09-30                          13694.0                  32827.44
# 2019-10-31                            597.0                   2015.54
# 2019-11-30                         -12358.0                 -30150.22
# 2019-12-31                           1368.0                   4641.03
# 2020-01-31                         -19252.0                 -41816.13
# 2020-02-29                           3873.0                   5518.69
# 2020-03-31                         -37374.0                 -83487.53
# 2020-04-30                         -37448.0                 -94968.42
# 2020-05-31                           1256.0                   3913.25
# 2020-06-30                           1313.0                   3949.55
# 2020-07-31                            721.0                   1478.70
# 2020-08-31                           1216.0                   2846.84
#
#                  first_diff_fare_amount  first_diff_congestion_surcharge  \
# pickup_datetime
# 2019-01-31                          NaN                              NaN
# 2019-02-28                    963050.67                         49322.25
# 2019-03-31                    230706.42                          9350.00
# 2019-04-30                   -304022.39                          -297.25
# 2019-05-31                    -12777.39                          -404.25
# 2019-06-30                    -69902.46                         -3776.25
# 2019-07-31                   -295822.26                         -9085.50
# 2019-08-31                   -130357.44                         -2275.50
# 2019-09-30                    156633.56                          7961.50
# 2019-10-31                      2253.89                          1709.75
# 2019-11-30                   -125543.19                         -7725.50
# 2019-12-31                     15704.15                           656.25
# 2020-01-31                   -186907.03                         -5741.00
# 2020-02-29                     31640.09                          1457.25
# 2020-03-31                   -339758.38                        -19444.25
# 2020-04-30                   -377918.68                        -20550.00
# 2020-05-31                     14739.02                           647.50
# 2020-06-30                     16498.58                           597.50
# 2020-07-31                      7728.89                           567.50
# 2020-08-31                     12327.62                           337.50
#
#                  first_diff_tip_amount
# pickup_datetime
# 2019-01-31                         NaN
# 2019-02-28                    81004.55
# 2019-03-31                    29215.65
# 2019-04-30                    -5645.21
# 2019-05-31                     7179.62
# 2019-06-30                   -12602.92
# 2019-07-31                   -31301.91
# 2019-08-31                    -6484.90
# 2019-09-30                    26308.25
# 2019-10-31                     7791.13
# 2019-11-30                   -17499.97
# 2019-12-31                     6211.06
# 2020-01-31                   -23634.83
# 2020-02-29                     6575.06
# 2020-03-31                   -51885.32
# 2020-04-30                   -51267.11
# 2020-05-31                     1856.25
# 2020-06-30                     2049.21
# 2020-07-31                      502.63
# 2020-08-31                      926.02

# %% [markdown]
# Use the coefficient of correlation between two values in a time series, the autocorrelation function (ACF), to identify seasonality in our time series data.
#
# Use the ACF plot, a bar chart of the coefficients of correlation between a time series and lags of itself, to pick the points that are statistically significant (outside the blue shaded Confidence Interval region).
#
# Use the Partial autocorrelation (PACF), a statistical measure that captures the correlation between two variables after controlling for the effects of other variables, to confirm the statistically significant lags.

# %%
plot_acf(df_model['passenger_count'], lags=23);

# %%
# Generate the PACF plot 

plot_pacf( df_model['passenger_count'], lags=11);

# %%
df_model.columns
# Out:
# Index(['passenger_count', 'trip_distance', 'fare_amount', 'tip_amount',
#        'tolls_amount', 'congestion_surcharge', 'first_diff_passenger_count',
#        'first_diff_trip_distance', 'first_diff_fare_amount',
#        'first_diff_congestion_surcharge', 'first_diff_tip_amount'],
#       dtype='object')

# %%
# Subset our data. Use our differenced columns
df_ts = df_model[['first_diff_passenger_count',
       'first_diff_trip_distance', 'first_diff_fare_amount',
       'first_diff_congestion_surcharge', 'first_diff_tip_amount']]

# Let's get rid of rows containing missing values.
df_ts.dropna(inplace = True)

df_ts
# Out:
# /Users/jonathanbeltran/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                  first_diff_passenger_count  first_diff_trip_distance  \
# pickup_datetime
# 2019-02-28                          85582.0                 254542.74
# 2019-03-31                          22770.0                  58715.75
# 2019-04-30                         -17651.0                 -88233.68
# 2019-05-31                          -2464.0                 -11310.89
# 2019-06-30                          -8036.0                 -20093.50
# 2019-07-31                         -25700.0                 -71903.30
# 2019-08-31                          -7223.0                 -32322.54
# 2019-09-30                          13694.0                  32827.44
# 2019-10-31                            597.0                   2015.54
# 2019-11-30                         -12358.0                 -30150.22
# 2019-12-31                           1368.0                   4641.03
# 2020-01-31                         -19252.0                 -41816.13
# 2020-02-29                           3873.0                   5518.69
# 2020-03-31                         -37374.0                 -83487.53
# 2020-04-30                         -37448.0                 -94968.42
# 2020-05-31                           1256.0                   3913.25
# 2020-06-30                           1313.0                   3949.55
# 2020-07-31                            721.0                   1478.70
# 2020-08-31                           1216.0                   2846.84
# 2020-09-30                           2002.0                   4710.84
# 2020-10-31                            661.0                   4553.03
# 2020-11-30                          -1041.0                  -1687.05
# 2020-12-31                          -1362.0                  -4541.71
#
#                  first_diff_fare_amount  first_diff_congestion_surcharge  \
# pickup_datetime
# 2019-02-28                    963050.67                         49322.25
# 2019-03-31                    230706.42                          9350.00
# 2019-04-30                   -304022.39                          -297.25
# 2019-05-31                    -12777.39                          -404.25
# 2019-06-30                    -69902.46                         -3776.25
# 2019-07-31                   -295822.26                         -9085.50
# 2019-08-31                   -130357.44                         -2275.50
# 2019-09-30                    156633.56                          7961.50
# 2019-10-31                      2253.89                          1709.75
# 2019-11-30                   -125543.19                         -7725.50
# 2019-12-31                     15704.15                           656.25
# 2020-01-31                   -186907.03                         -5741.00
# 2020-02-29                     31640.09                          1457.25
# 2020-03-31                   -339758.38                        -19444.25
# 2020-04-30                   -377918.68                        -20550.00
# 2020-05-31                     14739.02                           647.50
# 2020-06-30                     16498.58                           597.50
# 2020-07-31                      7728.89                           567.50
# 2020-08-31                     12327.62                           337.50
# 2020-09-30                     18906.31                          1345.00
# 2020-10-31                     13873.12                          1067.50
# 2020-11-30                     -7111.77                          -775.00
# 2020-12-31                    -16943.97                          -975.00
#
#                  first_diff_tip_amount
# pickup_datetime
# 2019-02-28                    81004.55
# 2019-03-31                    29215.65
# 2019-04-30                    -5645.21
# 2019-05-31                     7179.62
# 2019-06-30                   -12602.92
# 2019-07-31                   -31301.91
# 2019-08-31                    -6484.90
# 2019-09-30                    26308.25
# 2019-10-31                     7791.13
# 2019-11-30                   -17499.97
# 2019-12-31                     6211.06
# 2020-01-31                   -23634.83
# 2020-02-29                     6575.06
# 2020-03-31                   -51885.32
# 2020-04-30                   -51267.11
# 2020-05-31                     1856.25
# 2020-06-30                     2049.21
# 2020-07-31                      502.63
# 2020-08-31                      926.02
# 2020-09-30                     3300.91
# 2020-10-31                     3076.80
# 2020-11-30                    -1570.19
# 2020-12-31                    -2686.84

# %%
train, test = train_test_split(df_ts, shuffle=False, 
                               test_size = 0.05) # use small test size, as we can't predict far into the future
# Out of 131 rows (dropped one null), train has 124 and test has 7

# %%
# Instantiate a VAR model. 

model = VAR(train, dates = train.index, freq='M')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2 entries, 2020-11-30 to 2020-12-31
# Freq: M
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   first_diff_passenger_count       2 non-null      float64
#  1   first_diff_trip_distance         2 non-null      float64
#  2   first_diff_fare_amount           2 non-null      float64
#  3   first_diff_congestion_surcharge  2 non-null      float64
#  4   first_diff_tip_amount            2 non-null      float64
# dtypes: float64(5)
# memory usage: 96.0 bytes

# %%
# Fit our model and use AIC to select the value of p.

ts_model = model.fit(ic="aic")   # what "information criterion" (ic) will we use to decide what's "best?"

# %%
# What is the order of our autoregressive model? 
# Order ‘p’ means, up to p-lags of Y are used and they are the predictors in the equation
ts_model.k_ar
# Out:
# 2

# %%
# Check out the summary of our model!
ts_model.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 18, May, 2022
# Time:                     17:00:49
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                    88.1026
# Nobs:                     19.0000    HQIC:                   85.8314
# Log likelihood:          -890.802    FPE:                2.69769e+37
# AIC:                      85.3687    Det(Omega_mle):     2.74886e+36
# --------------------------------------------------------------------
# Results for equation first_diff_passenger_count
# =====================================================================================================
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                  -2768.949291      6197.543451           -0.447           0.655
# L1.first_diff_passenger_count              4.536144         4.381393            1.035           0.301
# L1.first_diff_trip_distance                1.758802         1.704045            1.032           0.302
# L1.first_diff_fare_amount                 -0.756942         0.558853           -1.354           0.176
# L1.first_diff_congestion_surcharge        -0.900578         4.091280           -0.220           0.826
# L1.first_diff_tip_amount                  -0.489003         1.941835           -0.252           0.801
# L2.first_diff_passenger_count              4.587989         3.688179            1.244           0.214
# L2.first_diff_trip_distance               -0.195580         1.602512           -0.122           0.903
# L2.first_diff_fare_amount                 -0.250542         0.452564           -0.554           0.580
# L2.first_diff_congestion_surcharge        -1.727288         2.103679           -0.821           0.412
# L2.first_diff_tip_amount                  -0.528201         1.054985           -0.501           0.617
# =====================================================================================================
#
# Results for equation first_diff_trip_distance
# =====================================================================================================
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                  -8789.941327     14753.136075           -0.596           0.551
# L1.first_diff_passenger_count             11.395469        10.429823            1.093           0.275
# L1.first_diff_trip_distance                4.507678         4.056446            1.111           0.266
# L1.first_diff_fare_amount                 -1.924111         1.330339           -1.446           0.148
# L1.first_diff_congestion_surcharge        -4.175672         9.739216           -0.429           0.668
# L1.first_diff_tip_amount                  -0.459867         4.622503           -0.099           0.921
# L2.first_diff_passenger_count             10.845923         8.779640            1.235           0.217
# L2.first_diff_trip_distance                0.653723         3.814749            0.171           0.864
# L2.first_diff_fare_amount                 -0.927230         1.077320           -0.861           0.389
# L2.first_diff_congestion_surcharge        -6.078495         5.007769           -1.214           0.225
# L2.first_diff_tip_amount                  -0.159132         2.511373           -0.063           0.949
# =====================================================================================================
#
# Results for equation first_diff_fare_amount
# =====================================================================================================
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                 -34683.684334     60836.654886           -0.570           0.569
# L1.first_diff_passenger_count             47.812779        43.008859            1.112           0.266
# L1.first_diff_trip_distance               17.733917        16.727332            1.060           0.289
# L1.first_diff_fare_amount                 -7.818042         5.485842           -1.425           0.154
# L1.first_diff_congestion_surcharge       -15.195203        40.161041           -0.378           0.705
# L1.first_diff_tip_amount                  -2.768612        19.061548           -0.145           0.885
# L2.first_diff_passenger_count             45.033141        36.204094            1.244           0.214
# L2.first_diff_trip_distance                2.709502        15.730660            0.172           0.863
# L2.first_diff_fare_amount                 -3.870664         4.442482           -0.871           0.384
# L2.first_diff_congestion_surcharge       -21.830148        20.650247           -1.057           0.290
# L2.first_diff_tip_amount                  -1.605668        10.356003           -0.155           0.877
# =====================================================================================================
#
# Results for equation first_diff_congestion_surcharge
# =====================================================================================================
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                   -236.896849      3157.559109           -0.075           0.940
# L1.first_diff_passenger_count              2.468540         2.232256            1.106           0.269
# L1.first_diff_trip_distance                0.777981         0.868186            0.896           0.370
# L1.first_diff_fare_amount                 -0.359632         0.284728           -1.263           0.207
# L1.first_diff_congestion_surcharge        -0.409323         2.084448           -0.196           0.844
# L1.first_diff_tip_amount                  -0.331626         0.989337           -0.335           0.737
# L2.first_diff_passenger_count              2.417289         1.879074            1.286           0.198
# L2.first_diff_trip_distance               -0.272855         0.816457           -0.334           0.738
# L2.first_diff_fare_amount                 -0.076119         0.230575           -0.330           0.741
# L2.first_diff_congestion_surcharge        -0.693226         1.071794           -0.647           0.518
# L2.first_diff_tip_amount                  -0.458404         0.537500           -0.853           0.394
# =====================================================================================================
#
# Results for equation first_diff_tip_amount
# =====================================================================================================
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                   -904.290517      8769.071533           -0.103           0.918
# L1.first_diff_passenger_count              6.795010         6.199351            1.096           0.273
# L1.first_diff_trip_distance                2.239453         2.411099            0.929           0.353
# L1.first_diff_fare_amount                 -1.040930         0.790736           -1.316           0.188
# L1.first_diff_congestion_surcharge        -1.227269         5.788863           -0.212           0.832
# L1.first_diff_tip_amount                  -0.759481         2.747555           -0.276           0.782
# L2.first_diff_passenger_count              6.786952         5.218503            1.301           0.193
# L2.first_diff_trip_distance               -0.080274         2.267437           -0.035           0.972
# L2.first_diff_fare_amount                 -0.414623         0.640345           -0.647           0.517
# L2.first_diff_congestion_surcharge        -2.188001         2.976552           -0.735           0.462
# L2.first_diff_tip_amount                  -0.922124         1.492727           -0.618           0.537
# =====================================================================================================
#
# Correlation matrix of residuals
#                                    first_diff_passenger_count  first_diff_trip_distance  first_diff_fare_amount  first_diff_congestion_surcharge  first_diff_tip_amount
# first_diff_passenger_count                           1.000000                  0.993274                0.992557                         0.966403               0.987812
# first_diff_trip_distance                             0.993274                  1.000000                0.998572                         0.940062               0.965956
# first_diff_fare_amount                               0.992557                  0.998572                1.000000                         0.936685               0.965853
# first_diff_congestion_surcharge                      0.966403                  0.940062                0.936685                         1.000000               0.984395
# first_diff_tip_amount                                0.987812                  0.965956                0.965853                         0.984395               1.000000

# %%
# Plot our training data.
ts_model.plot();
plt.tight_layout()

# %%
# Plot the forecast looking 3 steps ahead.
ts_model.plot_forecast(steps=1);

# %%
# Plot the forecast looking 10 steps ahead.
ts_model.plot_forecast(steps=6);
plt.tight_layout()

# %%
# Plot the forecast looking 11 steps ahead.
ts_model.plot_forecast(steps=12);
plt.tight_layout()

# %%
#Plot the forecast for the whole test set (and overlay the actual test values)
model_axes = ts_model.plot_forecast(test.shape[0]);
for i,ax in enumerate(model_axes.get_axes()):
     plot_df = test.iloc[:,i].reset_index(drop = True)
     plot_df.index += len(train)
     plot_df.plot(ax = ax, label = test.columns[i], color = 'red', alpha = 0.5)
     # zoom in 
     #plt.xlim(plot_df.index[-6], plot_df.index[-1])
     #plt.xlim(y_train.index[-15], y_test.index[-1])
     
     ax.legend(loc=2) # upper left
plt.tight_layout();

# %%
##Evaluating

# %%
# We'll use RMSE

# Save forecasted values
forecast = ts_model.forecast(train.values, len(test))

# Loop through columns and get RMSE for each
for i in range(test.shape[1]):
    print(f'The test RMSE on the {test.columns[i]} data is: {round(mean_squared_error(squared=False, y_true=test.values[:, i], y_pred=forecast[:, i]), 4)}')
# Out:
# The test RMSE on the first_diff_passenger_count data is: 5311.1744
# The test RMSE on the first_diff_trip_distance data is: 13613.4285
# The test RMSE on the first_diff_fare_amount data is: 55020.7551
# The test RMSE on the first_diff_congestion_surcharge data is: 1895.0198
# The test RMSE on the first_diff_tip_amount data is: 4200.6015

# %%
## Start by making a dataframe of our model's forecasts
forecast_df = pd.DataFrame(data = ts_model.forecast(train.values, len(test)),
                           columns = test.columns, index = test.index)

# %%
## Then we can undifference our once-differenced columns
### We do this by taking the last value from the original column before our test data
### and adding the cumulative summed first differenced forecasts
forecast_df['forecast_fatals'] = df_model['fatals'].iloc[-len(test)-1]  + forecast_df['first_diff_fatals'].cumsum()
forecast_df['forecast_drunk_dr'] = df_model['drunk_dr'].iloc[-len(test)-1]  + forecast_df['first_diff_drunk_dr'].cumsum()
forecast_df['forecast_peds'] = df_model['peds'].iloc[-len(test)-1]  + forecast_df['first_diff_peds'].cumsum()
